# %% [markdown]
# # clone ros2 jazzy farness pkg repository

# %%
cd ~/ros2_ws/src

# %%
git clone https://github.com/ghaithmhamd/unitree-r1-robot-ros2.git

# %%
cd ~/ros2_ws

# %%
colcon build

# %%
source install/setup.bash
